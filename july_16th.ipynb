# %% [markdown]
# | HLD                    | LLD           |
# | ---------------------- | ------------- |
# | Separation of Concerns | SOLID         |
# | Modularity             | DRY           |
# | Scalability            | KISS          |
# | Security               | YAGNI         |
# | Fault Tolerance        | Clean Code    |
# | High Cohesion          | Encapsulation |
# | Loose Coupling         | Reusability   |
# | Deployment             | Testability   |

# %% [markdown]
# | Book                                                                | Why Read It                                 |
# | ------------------------------------------------------------------- | ------------------------------------------- |
# | **Clean Code** – Robert C. Martin                                   | Learn to write readable, maintainable code. |
# | **Clean Architecture** – Robert C. Martin                           | Understand how to structure applications.   |
# | **Designing Data-Intensive Applications (DDIA)** – Martin Kleppmann | One of the best books on scalable systems.  |
# | **The Pragmatic Programmer**                                        | Develop a professional engineering mindset. |
# | **System Design Interview (Vol. 1 & 2)** – Alex Xu                  | Great introduction to modern system design. |

# %% [markdown]
# (Design Patterns)
#
#
# | Pattern    | Use                          |
# | ---------- | ---------------------------- |
# | Singleton  | One instance (e.g., logger)  |
# | Factory    | Create objects cleanly       |
# | Strategy   | Switch algorithms at runtime |
# | Observer   | Notifications/events         |
# | Adapter    | Connect incompatible APIs    |
# | Builder    | Build complex objects        |
# | Repository | Database abstraction         |
