# %% [markdown]
# | Topic             | What                                      | Why                         | When                    | Memory Trick       |
# | ----------------- | ----------------------------------------- | --------------------------- | ----------------------- | ------------------ |
# | API Integration   | Connect frontend to backend               | Exchange data               | Every web app           | Phone Call 📞      |
# | React Query / SWR | Fetch, cache, and synchronize server data | Avoid manual fetching logic | Data-heavy applications | Smart Assistant 🧠 |
# | Authentication    | Verify user identity                      | Secure APIs                 | Login systems           | ID Card 🪪         |
# | Protected Routes  | Restrict page access                      | Prevent unauthorized access | Dashboards, Admin pages | Security Guard 🚪  |

# %% [markdown]
# User Login
#       │
#       ▼
# FastAPI
#       │
#       ▼
# JWT
#       │
#       ▼
# Browser Stores Token
#       │
#       ▼
# User Opens Dashboard
#       │
#       ▼
# Protected Route
#       │
#       ▼
# Token Exists?
#       │
#  ┌────┴─────┐
#  │          │
#  ▼          ▼
# Yes         No
#  │          │
#  ▼          ▼
# Dashboard  Login

# %%
""""  
1. User enters

Email
Password
        │
        ▼
2. FastAPI verifies password
        │
        ▼
3. Backend creates

Access Token (JWT)

Refresh Token
        │
        ▼
4. Browser stores them

(Cookie)
        │
        ▼
5. User opens

/dashboard
        │
        ▼
6. Protected Route

Checks

Access Token?
        │
   Yes ─────► Continue
   No  ─────► Login
        │
        ▼
7. React calls

GET /profile
        │
        ▼
Authorization:

Bearer Access Token
        │
        ▼
8. Backend verifies JWT
        │
        ▼
9. Returns Profile

"""

# %%
"""
                     HTTPS
                        │
                  Session Key
                 (Encrypt Data)
                        │
──────────────────────────────────── 

                Authentication
                        │
                 Email + Password
                        │
                        ▼
                  Backend Login
                        │
          ┌─────────────┴─────────────┐
          ▼                           ▼
   Access Token (JWT)         Refresh Token
          │                           │
          └─────────────┬─────────────┘
                        ▼
                Stored in Cookie
                        │
                        ▼
              Protected Route Checks
                        │
                        ▼
                 Allowed or Login

"""
