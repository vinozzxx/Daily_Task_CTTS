# %% [markdown]
# Day : 1
#
# Date : 07-Jul
#
# Training Topic : Introduction to Vibe Coding & Development Tools
# Key Topics : Cursor, Claude Code, GitHub Copilot, Development Environment Setup, Spec-First Development, JavaScript & TypeScript Basics
#
# Trainer : Siddiq

# %% [markdown]
# | Concept               | **What?**                                                     | **Why?**                             | **When to Use?**                         | **Memory Trick**              |
# | --------------------- | ------------------------------------------------------------- | ------------------------------------ | ---------------------------------------- | ----------------------------- |
# | **GitLens**           | VS Code extension that shows Git history, author, and changes | Understand who changed code and when | While working with Git projects          | 🔍 **Git X-Ray**              |
# | **Directory Path**    | Address of a file or folder in a computer                     | Locate files correctly               | Reading files, imports, configuration    | 🗺️ **Home Address**          |
# | **JavaScript**        | Dynamic scripting language                                    | Build interactive websites           | Frontend and backend (Node.js)           | 🚗 **Normal Car**             |
# | **TypeScript**        | JavaScript + static types                                     | Catch errors before running          | Large, maintainable projects             | 🚙 **Car with GPS**           |
# | **Synchronous**       | Tasks run one after another                                   | Simple execution                     | Small or dependent tasks                 | 🚶 **One Person in Line**     |
# | **Asynchronous**      | Tasks run without waiting                                     | Faster, non-blocking programs        | API calls, file downloads                | 🍽️ **Order Food, Eat Later** |
# | **Single Thread**     | One task at a time                                            | Simpler execution                    | JavaScript runtime                       | 👤 **One Worker**             |
# | **Multi Thread**      | Multiple tasks at the same time                               | Better performance                   | Java, Python threading, C#               | 👥 **Many Workers**           |
# | **Callback Hell**     | Nested callbacks become hard to read                          | Problem caused by async callbacks    | Older JavaScript code                    | 🪜 **Staircase of Doom**      |
# | **ORM**               | Converts database tables into objects                         | Avoid writing raw SQL repeatedly     | Django ORM, SQLAlchemy, Laravel Eloquent | 🗣️ **Translator**            |
# | **ClickHouse**        | High-speed analytical database                                | Process huge datasets quickly        | Analytics, dashboards, logs              | ⚡ **Formula 1 Database**      |
# | **package.json**      | Node.js project configuration                                 | Manage packages and scripts          | JavaScript/TypeScript projects           | 📦 **Node Project Box**       |
# | **composer.json**     | PHP project configuration                                     | Manage PHP packages                  | Laravel, Symfony projects                | 📦 **PHP Project Box**        |
# | **API Response**      | Data returned by an API                                       | Send results to client               | Every API request                        | 📬 **Reply Letter**           |
# | **CRUD**              | Create, Read, Update, Delete                                  | Basic database operations            | Every application                        | ✏️ **Notebook Actions**       |
# | **HTTP Status Codes** | Numbers showing request result                                | Tell client success or failure       | Every API response                       | 🚦 **Traffic Lights**         |
# | **CI/CD**             | Automates build, testing, and deployment                      | Faster and safer releases            | Modern software development              | 🤖 **Automatic Factory**      |
# | **Coding Standards**  | Rules for writing clean code                                  | Improve readability and teamwork     | Every project                            | 📏 **Rulebook**               |

# %% [markdown]
# | Standard                          | What                                    | Why                                  | When to Use              | Memory Trick             |
# | --------------------------------- | --------------------------------------- | ------------------------------------ | ------------------------ | ------------------------ |
# | **Meaningful Names**              | Use clear variable and function names   | Makes code easy to understand        | Always                   | 🏷️ **Good Names**       |
# | **Consistent Formatting**         | Keep spacing and indentation consistent | Improves readability                 | Always                   | 📏 **Neat Code**         |
# | **Comments (When Needed)**        | Explain *why*, not obvious *what*       | Helps others understand decisions    | Complex logic            | 💬 **Explain Why**       |
# | **DRY** (Don't Repeat Yourself)   | Don't duplicate code                    | Easier maintenance                   | When logic repeats       | 📋 **Write Once**        |
# | **KISS** (Keep It Simple, Stupid) | Prefer simple solutions                 | Easier to debug                      | Always                   | 😊 **Keep It Simple**    |
# | **SOLID**                         | Design object-oriented code well        | Makes code flexible and maintainable | OOP projects             | 🧱 **Strong Foundation** |
# | **Error Handling**                | Handle errors gracefully                | Prevents crashes                     | File, DB, API operations | 🛡️ **Be Prepared**      |
# | **Follow Language Style Guide**   | Follow official style rules             | Team consistency                     | Always                   | 📘 **Official Rules**    |
# | **Small Functions**               | One function = one job                  | Easier to test and reuse             | Always                   | 🔧 **One Job**           |
# | **Version Control**               | Use Git properly                        | Track changes and collaborate        | Every project            | 🌿 **Save History**      |

# %% [markdown]
# Introduction to Vibe Coding & Development Tools
# Cursor, Claude Code, GitHub Copilot, Development Environment Setup, Spec-First Development, JavaScript & TypeScript Basics
#
# | Feature                      | Cursor                           | Claude Code                                     | GitHub Copilot                            |
# | ---------------------------- | -------------------------------- | ----------------------------------------------- | ----------------------------------------- |
# | **Type**                     | AI-powered IDE                   | AI Coding Assistant (CLI/Desktop)               | AI Code Completion Assistant              |
# | **Developed By**             | Cursor AI                        | Anthropic                                       | GitHub & OpenAI                           |
# | **Best For**                 | End-to-end software development  | Planning, reasoning, debugging, code generation | Fast code completion and suggestions      |
# | **IDE**                      | Built on VS Code                 | Works with terminal/editor                      | VS Code, Visual Studio, JetBrains, Neovim |
# | **Code Completion**          | ✅ Excellent                      | ❌ Limited                                       | ✅ Excellent                               |
# | **Project Understanding**    | ✅ Full project context           | ✅ Strong repository understanding               | ⚠️ Limited to current context             |
# | **Chat with Codebase**       | ✅ Yes                            | ✅ Yes                                           | ✅ Yes (Copilot Chat)                      |
# | **Multi-file Editing**       | ✅ Excellent                      | ✅ Good                                          | ⚠️ Basic                                  |
# | **Code Generation**          | ✅ Excellent                      | ✅ Excellent                                     | ✅ Good                                    |
# | **Refactoring**              | ✅ Excellent                      | ✅ Excellent                                     | ✅ Good                                    |
# | **Debugging Support**        | ✅ Very Good                      | ✅ Excellent                                     | ✅ Good                                    |
# | **Documentation Generation** | ✅ Good                           | ⭐ Excellent                                     | ✅ Good                                    |
# | **Terminal Integration**     | ✅ Yes                            | ⭐ Native CLI experience                         | ⚠️ Limited                                |
# | **Learning Curve**           | Easy                             | Moderate                                        | Very Easy                                 |
# | **Primary Strength**         | AI-first development environment | Deep reasoning and architecture                 | Productivity and autocomplete             |
# | **Ideal Users**              | Full-stack developers            | Senior developers, architects                   | Beginners to experienced developers       |
# | **Pricing**                  | Paid (Free trial available)      | Paid                                            | Free & Paid plans                         |
#
#
#
#
# Development Environment Setup
# What is a Development Environment?
#
# A development environment is the collection of software and tools needed to write, test, debug, and run applications efficiently.
#
# Essential Tools
# Tool Purpose
# Operating System Windows, macOS, or Linux
# Git Version control
# GitHub Store and collaborate on code
# Node.js JavaScript runtime
# npm Package manager
# VS Code / Cursor Code editor / AI IDE
# GitHub Copilot AI code completion
# Claude Code AI coding assistant
# Terminal Execute commands
# Browser Test web applications
# Installation Flow
# Install Git
#       ↓
# Create GitHub Account
#       ↓
# Install Node.js
#       ↓
# Install Cursor or VS Code
#       ↓
# Install Extensions
#       ↓
# Install GitHub Copilot / Claude Code
#       ↓
# Create First Project
# Step 1: Install Git
#
# Purpose:
#
# Track code changes
# Collaborate with teams
# Push code to GitHub
#
# Commands:
#
# git --version
# git init
# git clone <repository-url>
# Step 2: Install Node.js
#
# Purpose:
#
# Run JavaScript outside the browser
# Install packages
# Build applications
#
# Commands:
#
# node -v
# npm -v
# Step 3: Install Cursor
#
# Benefits:
#
# AI-powered IDE
# Project-wide understanding
# AI chat
# Multi-file editing
# Built-in terminal
# Step 4: Install VS Code (Alternative)
#
# Popular extensions:
#
# GitHub Copilot
# ESLint
# Prettier
# Error Lens
# GitLens
# Live Server
# Docker (optional)
# Step 5: Configure Git
# git config --global user.name "Your Name"
#
# git config --global user.email "you@example.com"
# Step 6: Create a GitHub Repository
# git init
#
# git add .
#
# git commit -m "Initial Commit"
#
# git branch -M main
#
# git remote add origin <repository-url>
#
# git push -u origin main
# Step 7: Create Your First Project
# mkdir hello-world
#
# cd hello-world
#
# npm init -y
#
# Create index.js
#
# console.log("Hello AI Developers!");
#
# Run
#
# node index.js
#
# Output
#
# Hello AI Developers!
# Step 8: AI Setup
# Cursor
# Login
# Connect GitHub
# Open project
# Start chatting with AI
# GitHub Copilot
# Install extension
# Sign in
# Enable suggestions
# Claude Code
# Install
# Authenticate
# Open terminal
# Ask coding questions
# Recommended Folder Structure
# Development/
#
# ├── Projects/
#
# ├── Learning/
#
# ├── Practice/
#
# ├── Notes/
#
# └── GitHub/
#
#
#
#
# Enhanced Spec-First Development Workflow
#                      ┌─────────────────────────────┐
#                      │        Project Idea         │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │  Requirement Gathering      │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │  Specification Documents    │
#                      │   (Module-wise Specs)       │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │  Implementation Plan        │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │  Development Checklist      │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#          ┌────────────────────────────────────────────────────┐
#          │             .claude_memory / .claude               │
#          │                                                    │
#          │ • Project Architecture                             │
#          │ • Coding Standards (PSR-12)                        │
#          │ • SOLID Principles                                 │
#          │ • Naming Conventions                               │
#          │ • Folder Structure                                 │
#          │ • API Standards                                    │
#          │ • Database Standards                               │
#          │ • Git Workflow                                     │
#          │ • Testing Guidelines                               │
#          │ • Prompt Templates                                 │
#          │ • Project Context & Decisions                      │
#          └──────────────────────┬─────────────────────────────┘
#                                 │
#                                 ▼
#                      ┌─────────────────────────────┐
#                      │         AI Coding           │
#                      │  (Cursor / Claude Code)     │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │        Unit Testing         │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │      Code Review / QA       │
#                      └──────────────┬──────────────┘
#                                     │
#                                     ▼
#                      ┌─────────────────────────────┐
#                      │         Deployment          │
#                      └─────────────────────────────┘
# Recommended Project Structure
# project/
#
# docs/
# ├── IDEA.md
# ├── REQUIREMENTS.md
# ├── IMPLEMENTATION_PLAN.md
# ├── CHECKLIST.md
#
# specs/
# ├── authentication.md
# ├── user.md
# ├── booking.md
# ├── payment.md
#
# .claude_memory/
# ├── architecture.md
# ├── coding-standards.md
# ├── psr12.md
# ├── solid-principles.md
# ├── folder-structure.md
# ├── naming-conventions.md
# ├── api-guidelines.md
# ├── database-guidelines.md
# ├── testing-guidelines.md
# ├── git-workflow.md
# ├── prompt-templates.md
# └── project-context.md
#
# src/
# tests/
# README.md
# What goes into .claude_memory
# File Purpose
# architecture.md Overall system architecture
# coding-standards.md Team coding rules
# psr12.md PHP PSR-12 coding style
# solid-principles.md SOLID design principles
# folder-structure.md Project directory layout
# naming-conventions.md Variable, class, method naming
# api-guidelines.md REST API standards
# database-guidelines.md Database design rules
# testing-guidelines.md Unit and integration testing standards
# git-workflow.md Branching and commit conventions
# prompt-templates.md Reusable AI prompts
# project-context.md Business rules and project decisions
# Benefits
# Consistency: Every AI-generated file follows the same standards.
# Reduced Rework: Less time spent fixing formatting or architectural issues.
# Scalability: New developers or AI sessions can quickly understand the project.
# Maintainability: Coding standards, PSR-12, SOLID, and testing practices are applied uniformly.
# Better AI Results: Cursor and Claude Code generate higher-quality code when they have project memory and clear development standards.
#
#
# 1. What is JavaScript?
#
# JavaScript is a programming language used to build interactive web applications.
#
# Used For
#
# Frontend Development
# Backend (Node.js)
# Mobile Apps
# Desktop Apps
# AI Applications
# 2. What is TypeScript?
#
# TypeScript is a superset of JavaScript that adds static typing and better tooling.
#
# Benefits
#
# Type Safety
# Better IntelliSense
# Early Error Detection
# Easier Maintenance
# Ideal for Large Projects
# JavaScript vs TypeScript
# Feature JavaScript TypeScript
# Typing Dynamic Static
# Compilation No Yes (Compiles to JavaScript)
# Error Detection Runtime Compile Time
# IDE Support Good Excellent
# Learning Curve Easy Moderate
# Best For Small Projects Medium & Large Projects
# Variables
# JavaScript
# let name = "John";
# const age = 25;
# TypeScript
# let name: string = "John";
# const age: number = 25;
# Data Types
# JavaScript TypeScript
# String string
# Number number
# Boolean boolean
# Array string[]
# Object object
# Null null
# Undefined undefined
#
# Example
#
# let username: string = "Siddiq";
# let age: number = 30;
# let active: boolean = true;
# Functions
# JavaScript
# function add(a, b) {
#     return a + b;
# }
# TypeScript
# function add(a: number, b: number): number {
#     return a + b;
# }
# Objects
# JavaScript
# const user = {
#     name: "John",
#     age: 25
# };
# TypeScript
# const user: {
#     name: string;
#     age: number;
# } = {
#     name: "John",
#     age: 25
# };
# Arrays
# const fruits: string[] = [
#     "Apple",
#     "Orange",
#     "Mango"
# ];
# Interfaces (TypeScript)
# interface User {
#     id: number;
#     name: string;
#     email: string;
# }
#
# Using Interface
#
# const user: User = {
#     id: 1,
#     name: "John",
#     email: "john@test.com"
# };
# Classes
# class Employee {
#
#     constructor(
#         public id: number,
#         public name: string
#     ) {}
#
#     display() {
#         console.log(this.name);
#     }
# }
#
# const emp = new Employee(1, "John");
#
# emp.display();
# Arrow Function
# const greet = (name: string): string => {
#     return `Hello ${name}`;
# };
# Template String
# const name = "John";
#
# console.log(`Welcome ${name}`);
# Async / Await
# async function getUsers() {
#     const response = await fetch("/api/users");
#     return response.json();
# }
# JavaScript vs TypeScript Example
# JavaScript
# let age = "25";
#
# age = true;
#
# age = [];
#
# No compile-time error.
#
# TypeScript
# let age: number = 25;
#
# age = "Twenty Five";
#
# ❌ Compile-time error:
#
# Type 'string' is not assignable to type 'number'
